# %% [markdown]
# # **Loan Approvals**

# %% [markdown]
# *   `Gender` : Gender of Person
# *   `Married` : Marital Status
# *   `Dependents` : Number of dependents
# *   `Education` : Education Level
# *   `Self_Employed` : If they are self employed.
# *   `Applicant_Income` : Income of applicant
# *   `Coapplicant_Income` : Income of co applicant.
# *   `Loan_Amount` : Loan Amount
# *   `Term` : Term of loan
# *   `Credit_History` : If they have good/bad credit history.
# *   `Area` : Geographical Area
# *   `Status` : Loan approval status
#
# [Loan Approvals Dataset](https://www.kaggle.com/datasets/prateekmaj21/loan-approvals)

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.head(10)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male      No          0      Graduate            No            584900
# 1   Male     Yes          1      Graduate            No            458300
# 2   Male     Yes          0      Graduate           Yes            300000
# 3   Male     Yes          0  Not Graduate            No            258300
# 4   Male      No          0      Graduate            No            600000
# 5   Male     Yes          2      Graduate           Yes            541700
# 6   Male     Yes          0  Not Graduate            No            233300
# 7   Male     Yes         3+      Graduate            No            303600
# 8   Male     Yes          2      Graduate            No            400600
# 9   Male     Yes          1      Graduate            No           1284100
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 0                 0.0     15000000  360.0             1.0      Urban      Y
# 1            150800.0     12800000  360.0             1.0      Rural      N
# 2                 0.0      6600000  360.0             1.0      Urban      Y
# 3            235800.0     12000000  360.0             1.0      Urban      Y
# 4                 0.0     14100000  360.0             1.0      Urban      Y
# 5            419600.0     26700000  360.0             1.0      Urban      Y
# 6            151600.0      9500000  360.0             1.0      Urban      Y
# 7            250400.0     15800000  360.0             0.0  Semiurban      N
# 8            152600.0     16800000  360.0             1.0      Urban      Y
# 9           1096800.0     34900000  360.0             1.0  Semiurban      N

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              601 non-null    object
#  1   Married             611 non-null    object
#  2   Dependents          599 non-null    object
#  3   Education           614 non-null    object
#  4   Self_Employed       582 non-null    object
#  5   Applicant_Income    614 non-null    int64
#  6   Coapplicant_Income  614 non-null    float64
#  7   Loan_Amount         614 non-null    int64
#  8   Term                600 non-null    float64
#  9   Credit_History      564 non-null    float64
#  10  Area                614 non-null    object
#  11  Status              614 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 57.7+ KB

# %%
df.describe()
# Out:
#        Applicant_Income  Coapplicant_Income   Loan_Amount       Term  \
# count      6.140000e+02        6.140000e+02  6.140000e+02  600.00000
# mean       5.403459e+05        1.621246e+05  1.414104e+07  342.00000
# std        6.109042e+05        2.926248e+05  8.815682e+06   65.12041
# min        1.500000e+04        0.000000e+00  0.000000e+00   12.00000
# 25%        2.877500e+05        0.000000e+00  9.800000e+06  360.00000
# 50%        3.812500e+05        1.188500e+05  1.250000e+07  360.00000
# 75%        5.795000e+05        2.297250e+05  1.647500e+07  360.00000
# max        8.100000e+06        4.166700e+06  7.000000e+07  480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# !pip install summarytools
from summarytools import dfSummary
dfSummary(df)
# Out:
# Requirement already satisfied: summarytools in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from summarytools) (2.1.4)
# Requirement already satisfied: ipython>=7.20.0 in /usr/local/lib/python3.10/dist-packages (from summarytools) (7.34.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from summarytools) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from summarytools) (3.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (71.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.20.0->summarytools) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->summarytools) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->summarytools) (2024.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.20.0->summarytools) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.20.0->summarytools) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)
# <style type="text/css">
# #T_52610 thead>tr>th {
#   text-align: left;
# }
# #T_52610_row0_col0, #T_52610_row1_col0, #T_52610_row2_col0, #T_52610_row3_col0, #T_52610_row4_col0, #T_52610_row5_col0, #T_52610_row6_col0, #T_52610_row7_col0, #T_52610_row8_col0, #T_52610_row9_col0, #T_52610_row10_col0, #T_52610_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_52610_row0_col1, #T_52610_row1_col1, #T_52610_row2_col1, #T_52610_row3_col1, #T_52610_row4_col1, #T_52610_row5_col1, #T_52610_row6_col1, #T_52610_row7_col1, #T_52610_row8_col1, #T_52610_row9_col1, #T_52610_row10_col1, #T_52610_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_52610_row0_col2, #T_52610_row1_col2, #T_52610_row2_col2, #T_52610_row3_col2, #T_52610_row4_col2, #T_52610_row5_col2, #T_52610_row6_col2, #T_52610_row7_col2, #T_52610_row8_col2, #T_52610_row9_col2, #T_52610_row10_col2, #T_52610_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_52610_row0_col3, #T_52610_row1_col3, #T_52610_row2_col3, #T_52610_row3_col3, #T_52610_row4_col3, #T_52610_row5_col3, #T_52610_row6_col3, #T_52610_row7_col3, #T_52610_row8_col3, #T_52610_row9_col3, #T_52610_row10_col3, #T_52610_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_52610_row0_col4, #T_52610_row1_col4, #T_52610_row2_col4, #T_52610_row3_col4, #T_52610_row4_col4, #T_52610_row5_col4, #T_52610_row6_col4, #T_52610_row7_col4, #T_52610_row8_col4, #T_52610_row9_col4, #T_52610_row10_col4, #T_52610_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_52610_row0_col5, #T_52610_row1_col5, #T_52610_row2_col5, #T_52610_row3_col5, #T_52610_row4_col5, #T_52610_row5_col5, #T_52610_row6_col5, #T_52610_row7_col5, #T_52610_row8_col5, #T_52610_row9_col5, #T_52610_row10_col5, #T_52610_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_52610" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 614 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_52610_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_52610_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_52610_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_52610_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_52610_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_52610_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52610_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_52610_row0_col1" class="data row0 col1" ><strong>Gender</strong><br>[object]</td>
#       <td id="T_52610_row0_col2" class="data row0 col2" >1. Male<br>2. Female<br>3. nan</td>
#       <td id="T_52610_row0_col3" class="data row0 col3" >489 (79.6%)<br>112 (18.2%)<br>13 (2.1%)</td>
#       <td id="T_52610_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row0_col5" class="data row0 col5" >13<br>(2.1%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_52610_row1_col1" class="data row1 col1" ><strong>Married</strong><br>[object]</td>
#       <td id="T_52610_row1_col2" class="data row1 col2" >1. Yes<br>2. No<br>3. nan</td>
#       <td id="T_52610_row1_col3" class="data row1 col3" >398 (64.8%)<br>213 (34.7%)<br>3 (0.5%)</td>
#       <td id="T_52610_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row1_col5" class="data row1 col5" >3<br>(0.5%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_52610_row2_col1" class="data row2 col1" ><strong>Dependents</strong><br>[object]</td>
#       <td id="T_52610_row2_col2" class="data row2 col2" >1. 0<br>2. 1<br>3. 2<br>4. 3+<br>5. nan</td>
#       <td id="T_52610_row2_col3" class="data row2 col3" >345 (56.2%)<br>102 (16.6%)<br>101 (16.4%)<br>51 (8.3%)<br>15 (2.4%)</td>
#       <td id="T_52610_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row2_col5" class="data row2 col5" >15<br>(2.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_52610_row3_col1" class="data row3 col1" ><strong>Education</strong><br>[object]</td>
#       <td id="T_52610_row3_col2" class="data row3 col2" >1. Graduate<br>2. Not Graduate</td>
#       <td id="T_52610_row3_col3" class="data row3 col3" >480 (78.2%)<br>134 (21.8%)</td>
#       <td id="T_52610_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_52610_row4_col1" class="data row4 col1" ><strong>Self_Employed</strong><br>[object]</td>
#       <td id="T_52610_row4_col2" class="data row4 col2" >1. No<br>2. Yes<br>3. nan</td>
#       <td id="T_52610_row4_col3" class="data row4 col3" >500 (81.4%)<br>82 (13.4%)<br>32 (5.2%)</td>
#       <td id="T_52610_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row4_col5" class="data row4 col5" >32<br>(5.2%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_52610_row5_col1" class="data row5 col1" ><strong>Applicant_Income</strong><br>[int64]</td>
#       <td id="T_52610_row5_col2" class="data row5 col2" >Mean (sd) : 540345.9 (610904.2)<br>min < med < max:<br>15000.0 < 381250.0 < 8100000.0<br>IQR (CV) : 291750.0 (0.9)</td>
#       <td id="T_52610_row5_col3" class="data row5 col3" >505 distinct values</td>
#       <td id="T_52610_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_52610_row6_col1" class="data row6 col1" ><strong>Coapplicant_Income</strong><br>[float64]</td>
#       <td id="T_52610_row6_col2" class="data row6 col2" >Mean (sd) : 162124.6 (292624.8)<br>min < med < max:<br>0.0 < 118850.0 < 4166700.0<br>IQR (CV) : 229725.0 (0.6)</td>
#       <td id="T_52610_row6_col3" class="data row6 col3" >287 distinct values</td>
#       <td id="T_52610_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_52610_row7_col1" class="data row7 col1" ><strong>Loan_Amount</strong><br>[int64]</td>
#       <td id="T_52610_row7_col2" class="data row7 col2" >Mean (sd) : 14141042.3 (8815682.5)<br>min < med < max:<br>0.0 < 12500000.0 < 70000000.0<br>IQR (CV) : 6675000.0 (1.6)</td>
#       <td id="T_52610_row7_col3" class="data row7 col3" >204 distinct values</td>
#       <td id="T_52610_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_52610_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_52610_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_52610_row8_col1" class="data row8 col1" ><strong>Term</strong><br>[float64]</td>
#       <td id="T_52610_row8_col2" class="data row8 col2" >1. 360.0<br>2. 180.0<br>3. 480.0<br>4. nan<br>5. 300.0<br>6. 240.0<br>7. 84.0<br>8. 120.0<br>9. 60.0<br>10. 36.0<br>11. other</td>
#       <td id="T_52610_row8_col3" class="data row8 col3" >512 (83.4%)<br>44 (7.2%)<br>15 (2.4%)<br>14 (2.3%)<br>13 (2.1%)<br>4 (0.7%)<br>4 (0.7%)<br>3 (0.5%)<br>2 (0.3%)<br>2 (0.3%)<br>1 (0.2%)</td>
#       <

# %% [markdown]
# ### **Data Cleansing**

# %%
# Checking missing value
df.isnull().sum()
# Out:
# Gender                13
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                  14
# Credit_History        50
# Area                   0
# Status                 0
# dtype: int64

# %% [markdown]
# **fill the nan value in the `Gender` column with the mode value**

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
#Tracking missing value in Gender
df[df['Gender'].isna()==1]
# Out:
#     Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 23     NaN     Yes          2  Not Graduate            No            336500
# 126    NaN     Yes         3+      Graduate            No           2380300
# 171    NaN     Yes         3+      Graduate            No           5176300
# 188    NaN     Yes          0      Graduate           Yes             67400
# 314    NaN     Yes          0      Graduate            No            247300
# 334    NaN     Yes          1      Graduate           Yes            983300
# 460    NaN     Yes          0      Graduate           Yes            208300
# 467    NaN     Yes          0      Graduate            No           1669200
# 477    NaN     Yes          2      Graduate            No            287300
# 507    NaN      No          0      Graduate            No            358300
# 576    NaN     Yes          0      Graduate            No            308700
# 588    NaN      No          0      Graduate            No            475000
# 592    NaN      No         3+      Graduate           Yes            935700
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 23             191700.0     11200000  360.0             0.0      Rural      N
# 126                 0.0     37000000  360.0             1.0      Rural      Y
# 171                 0.0     70000000  300.0             1.0      Urban      Y
# 188            529600.0     16800000  360.0             1.0      Rural      Y
# 314            184300.0     15900000  360.0             1.0      Rural      N
# 334            183300.0     18200000  180.0             1.0      Urban      Y
# 460            408300.0     16000000  360.0             NaN  Semiurban      Y
# 467                 0.0     11000000  360.0             1.0  Semiurban      Y
# 477            187200.0     13200000  360.0             0.0  Semiurban      N
# 507                 0.0      9600000  360.0             1.0      Urban      N
# 576            221000.0     13600000  360.0             0.0  Semiurban      N
# 588                 0.0      9400000  360.0             1.0  Semiurban      Y
# 592                 0.0     29200000  360.0             1.0  Semiurban      Y

# %%
mode_gender = df['Gender'].mode()[0]
df['Gender'].fillna(mode_gender,inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %% [markdown]
# **fill the nan value in the `Self_Employee` column with the mode value**

# %%
df.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
df[df['Self_Employed'].isna()==1]
# Out:
#      Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 11     Male     Yes          2      Graduate           NaN            250000
# 19     Male     Yes          0      Graduate           NaN            260000
# 24     Male     Yes          1      Graduate           NaN            371700
# 29   Female      No          2      Graduate           NaN            375000
# 30     Male     Yes          1      Graduate           NaN            416600
# 95     Male      No          0      Graduate           NaN            678200
# 107    Male      No          0  Not Graduate           NaN            733300
# 111  Female     Yes          0      Graduate           NaN            292900
# 114    Male      No          0      Graduate           NaN            505000
# 158    Male      No          0      Graduate           NaN            298000
# 170    Male     Yes          0  Not Graduate           NaN            182000
# 218    Male     Yes          2      Graduate           NaN            500000
# 231    Male     Yes          0      Graduate           NaN            371600
# 236    Male     Yes          0      Graduate           NaN            574600
# 268  Female      No          0      Graduate           NaN            341800
# 295    Male     Yes         3+      Graduate           NaN            441600
# 333    Male     Yes          0      Graduate           NaN           6333700
# 336    Male     Yes          1      Graduate           NaN            525000
# 344    Male     Yes          2      Graduate           NaN            258300
# 374  Female      No          0      Graduate           NaN            276400
# 380    Male     Yes          0      Graduate           NaN            333300
# 385    Male      No          1      Graduate           NaN            366700
# 411    Male     Yes          0      Graduate           NaN            625600
# 432    Male      No          0      Graduate           NaN           1287600
# 447    Male     Yes          0      Graduate           NaN            353900
# 463  Female      No          1  Not Graduate           NaN            519100
# 468  Female     Yes          2  Not Graduate           NaN             21000
# 535    Male      No          0  Not Graduate           NaN            255000
# 542  Female      No          1      Graduate           NaN            365200
# 579    Male      No          0      Graduate           NaN            318200
# 600  Female      No         3+      Graduate           NaN             41600
# 601    Male     Yes          0  Not Graduate           NaN            289400
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 11             184000.0     10900000  360.0             1.0      Urban      Y
# 19             350000.0     11500000    NaN             1.0      Urban      Y
# 24             292500.0     15100000  360.0             NaN  Semiurban      N
# 29             208300.0     12000000  360.0             1.0  Semiurban      Y
# 30             336900.0     20100000  360.0             NaN      Urban      N
# 95                  0.0            0  360.0             NaN      Urban      N
# 107                 0.0     12000000  360.0             1.0      Rural      N
# 111            233300.0     13900000  360.0             1.0  Semiurban      Y
# 114                 0.0     11800000  360.0             1.0  Semiurban      Y
# 158            208300.0     12000000  360.0             1.0      Rural      Y
# 170            176900.0      9500000  360.0             1.0      Rural      Y
# 218                 0.0      7200000  360.0             0.0  Semiurban      N
# 231                 0.0      4200000  180.0             1.0      Rural      Y
# 236                 0.0     25500000  360.0             NaN      Urban      N
# 268                 0.0     13500000  360.0             1.0      Rural      N
# 295            125000.0     11000000  360.0             1.0      Urban      Y
# 333                 0.0     49000000  180.0             1.0      Urban      Y
# 336             68800.0     16000000  360.0             1.0      Rural      Y
# 344            233000.0     12500000  360.0             1.0      Rural      Y
# 374            145900.0     11000000  360.0             1.0      Urban      Y
# 380            250000.0     12800000  360.0             1.0  Semiurban      Y
# 385                 0.0     11300000  180.0             1.0      Urban      Y
# 411                 0.0     16000000  360.0             NaN      Urban      Y
# 432                 0.0     40500000  360.0             1.0  Semiurban      Y
# 447            137600.0      5500000  360.0             1.0      Rural      N
# 463                 0.0     13200000  360.0             1.0  Semiurban      Y
# 468            291700.0      9800000  360.0             1.0  Semiurban      Y
# 535            204200.0     12600000  360.0             1.0      Rural      Y
# 542                 0.0      9500000  360.0             1.0  Semiurban      Y
# 579            291700.0     16100000  360.0             1.0      Urban      Y
# 600           4166700.0     35000000  180.0             NaN      Urban      N
# 601            279200.0     15500000  360.0             1.0      Rural      Y

# %%
Self_employed_value = df['Self_Employed'].mode()[0]
df['Self_Employed'].fillna(Self_employed_value, inplace=True)

# %%
df['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64

# %% [markdown]
# **fill the nan value in the `Dependents` column with the mode value and change `3+` to `3` and astype to Int**

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df[df['Dependents'].isna()==1]
# Out:
#      Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 102    Male     Yes        NaN      Graduate            No           1365000
# 104    Male     NaN        NaN      Graduate            No            381600
# 120    Male     Yes        NaN      Graduate            No            566700
# 226    Male     Yes        NaN  Not Graduate           Yes            473500
# 228    Male     NaN        NaN      Graduate            No            475800
# 293  Female      No        NaN      Graduate            No            541700
# 301    Male     Yes        NaN  Not Graduate            No            287500
# 332    Male      No        NaN      Graduate            No            283300
# 335    Male     Yes        NaN      Graduate           Yes            550300
# 346    Male     Yes        NaN  Not Graduate            No            352300
# 355  Female      No        NaN      Graduate            No            381300
# 435  Female     NaN        NaN      Graduate            No           1004700
# 517    Male     Yes        NaN  Not Graduate            No            307400
# 571    Male     Yes        NaN      Graduate            No            511600
# 597    Male      No        NaN      Graduate            No            298700
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 102                 0.0            0  360.0             1.0      Urban      Y
# 104             75400.0     16000000  360.0             1.0      Urban      Y
# 120            266700.0     18000000  360.0             1.0      Rural      Y
# 226                 0.0     13800000  360.0             1.0      Urban      N
# 228                 0.0     15800000  480.0             1.0  Semiurban      Y
# 293                 0.0     14300000  480.0             0.0      Urban      N
# 301            175000.0     10500000  360.0             1.0  Semiurban      Y
# 332                 0.0      7100000  360.0             1.0      Urban      Y
# 335            449000.0      7000000    NaN             1.0  Semiurban      Y
# 346            323000.0     15200000  360.0             0.0      Rural      N
# 355                 0.0     11600000  180.0             1.0      Urban      Y
# 435                 0.0            0  240.0             1.0  Semiurban      Y
# 517            180000.0     12300000  360.0             0.0  Semiurban      N
# 571            145100.0     16500000  360.0             0.0      Urban      N
# 597                 0.0      8800000  360.0             0.0  Semiurban      N

# %%
mode_dependents = df['Dependents'].mode()[0]
df['Dependents'].fillna(mode_dependents, inplace=True)

# %%
df['Dependents'] = df['Dependents'].replace('3+', 3)
df['Dependents'] = df['Dependents'].astype(int)

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0    360
# 1    102
# 2    101
# 3     51
# Name: count, dtype: int64

# %% [markdown]
# fill the nan value in the Credit_history_mode column with the mode value

# %%
credit_history_mode = df['Credit_History'].mode()[0]
df['Credit_History'].fillna(credit_history_mode, inplace=True)

# %%
df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    525
# 0.0     89
# Name: count, dtype: int64

# %%
df['Credit_History'] = df['Credit_History'].replace(1.0, 'Yes')
df['Credit_History'] = df['Credit_History'].replace(0.0, 'No')
df['Credit_History'].value_counts()
# Out:
# Credit_History
# Yes    525
# No      89
# Name: count, dtype: int64

# %% [markdown]
# fill the nan value in the `Married` column with the mode value

# %%
df[df['Married'].isna()==1]
# Out:
#      Gender Married  Dependents Education Self_Employed  Applicant_Income  \
# 104    Male     NaN           0  Graduate            No            381600
# 228    Male     NaN           0  Graduate            No            475800
# 435  Female     NaN           0  Graduate            No           1004700
#
#      Coapplicant_Income  Loan_Amount   Term Credit_History       Area Status
# 104             75400.0     16000000  360.0            Yes      Urban      Y
# 228                 0.0     15800000  480.0            Yes  Semiurban      Y
# 435                 0.0            0  240.0            Yes  Semiurban      Y

# %%
df['Married'].fillna(df['Married'].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Gender                 0
# Married                0
# Dependents             0
# Education              0
# Self_Employed          0
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                  14
# Credit_History         0
# Area                   0
# Status                 0
# dtype: int64

# %% [markdown]
# fill the nan value in the `Term` column with the mode value

# %%
df['Term'].value_counts()
# Out:
# Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
df[df['Term'].isna()==1]
# Out:
#      Gender Married  Dependents     Education Self_Employed  Applicant_Income  \
# 19     Male     Yes           0      Graduate            No            260000
# 36     Male     Yes           0      Graduate            No            182800
# 44     Male     Yes           0  Not Graduate           Yes            469500
# 45   Female      No           0      Graduate            No            341000
# 73     Male     Yes           3  Not Graduate            No            475500
# 112    Male     Yes           0  Not Graduate            No            357200
# 165    Male     Yes           0      Graduate            No            370700
# 197  Female      No           0  Not Graduate            No            190700
# 223    Male     Yes           0      Graduate            No            757800
# 232    Male      No           0  Not Graduate            No            318900
# 335    Male     Yes           0      Graduate           Yes            550300
# 367    Male      No           0      Graduate            No            512400
# 421  Female      No           0  Not Graduate            No            272000
# 423    Male     Yes           1      Graduate            No            725000
#
#      Coapplicant_Income  Loan_Amount  Term Credit_History       Area Status
# 19             350000.0     11500000   NaN            Yes      Urban      Y
# 36             133000.0     10000000   NaN             No      Urban      N
# 44                  0.0      9600000   NaN            Yes      Urban      Y
# 45                  0.0      8800000   NaN            Yes      Urban      Y
# 73                  0.0      9500000   NaN             No  Semiurban      N
# 112            411400.0     15200000   NaN             No      Rural      N
# 165            316600.0     18200000   NaN            Yes      Rural      Y
# 197            236500.0     12000000   NaN            Yes      Urban      Y
# 223            101000.0     17500000   NaN            Yes  Semiurban      Y
# 232            259800.0     12000000   NaN            Yes      Rural      Y
# 335            449000.0      7000000   NaN            Yes  Semiurban      Y
# 367                 0.0     12400000   NaN             No      Rural      N
# 421                 0.0      8000000   NaN             No      Urban      N
# 423            166700.0     11000000   NaN             No      Urban      N

# %%
df['Term'].fillna(df['Term'].median(), inplace=True)

# %%
df['Term'].value_counts()
# Out:
# Term
# 360.0    526
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
#Handling missing data completed
df.isna().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# Applicant_Income      0
# Coapplicant_Income    0
# Loan_Amount           0
# Term                  0
# Credit_History        0
# Area                  0
# Status                0
# dtype: int64

# %%
categorical_data = df.select_dtypes(include=['object'])
categorical_data
# Out:
#      Gender Married     Education Self_Employed Credit_History       Area  \
# 0      Male      No      Graduate            No            Yes      Urban
# 1      Male     Yes      Graduate            No            Yes      Rural
# 2      Male     Yes      Graduate           Yes            Yes      Urban
# 3      Male     Yes  Not Graduate            No            Yes      Urban
# 4      Male      No      Graduate            No            Yes      Urban
# ..      ...     ...           ...           ...            ...        ...
# 609  Female      No      Graduate            No            Yes      Rural
# 610    Male     Yes      Graduate            No            Yes      Rural
# 611    Male     Yes      Graduate            No            Yes      Urban
# 612    Male     Yes      Graduate            No            Yes      Urban
# 613  Female      No      Graduate           Yes             No  Semiurban
#
#     Status
# 0        Y
# 1        N
# 2        Y
# 3        Y
# 4        Y
# ..     ...
# 609      Y
# 610      Y
# 611      Y
# 612      Y
# 613      N
#
# [614 rows x 7 columns]

# %%
plt.figure(figsize=(15,10))
num_cols = len(categorical_data.columns)
for i, col in enumerate(categorical_data.columns):
    plt.subplot(1, num_cols, i + 1)
    sns.countplot(x=df[col], color='blue')
    plt.title(col)
    plt.tight_layout()

# %%
numerical_data = df.select_dtypes(include=['int64', 'float64'])
numerical_data.head()
# Out:
#    Dependents  Applicant_Income  Coapplicant_Income  Loan_Amount   Term
# 0           0            584900                 0.0     15000000  360.0
# 1           1            458300            150800.0     12800000  360.0
# 2           0            300000                 0.0      6600000  360.0
# 3           0            258300            235800.0     12000000  360.0
# 4           0            600000                 0.0     14100000  360.0

# %%
#bins of data
df.hist(figsize=(5,10))
plt.show()

# %%
#numerical data
plt.figure(figsize=(20,10))
correlation_matrix = numerical_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(data=df, hue='Status')

# %%
sns.pairplot(data=df, hue='Gender')

# %% [markdown]
# Bivariate Analysis

# %%
df.groupby('Status')['Applicant_Income'].describe().T
# Out:
# Status             N             Y
# count   1.920000e+02  4.220000e+02
# mean    5.446078e+05  5.384069e+05
# std     6.819559e+05  5.765442e+05
# min     1.500000e+04  2.100000e+04
# 25%     2.885000e+05  2.877500e+05
# 50%     3.833500e+05  3.812500e+05
# 75%     5.861250e+05  5.771500e+05
# max     8.100000e+06  6.333700e+06

# %%
df.groupby('Gender')[['Applicant_Income']].describe().T
# Out:
# Gender                        Female          Male
# Applicant_Income count  1.120000e+02  5.020000e+02
#                  mean   4.643473e+05  5.573018e+05
#                  std    3.585381e+05  6.531266e+05
#                  min    2.100000e+04  1.500000e+04
#                  25%    2.661500e+05  2.900500e+05
#                  50%    3.583000e+05  3.862000e+05
#                  75%    4.606500e+05  5.939500e+05
#                  max    1.948400e+06  8.100000e+06

# %%
df.groupby('Married')[['Applicant_Income','Loan_Amount']].describe().T
# Out:
# Married                           No           Yes
# Applicant_Income count  2.130000e+02  4.010000e+02
#                  mean   4.970385e+05  5.633496e+05
#                  std    4.004333e+05  6.967223e+05
#                  min    4.160000e+04  1.500000e+04
#                  25%    2.917000e+05  2.873000e+05
#                  50%    3.750000e+05  3.859000e+05
#                  75%    5.417000e+05  5.821000e+05
#                  max    3.771900e+06  8.100000e+06
# Loan_Amount      count  2.130000e+02  4.010000e+02
#                  mean   1.253521e+07  1.499401e+07
#                  std    7.622511e+06  9.284569e+06
#                  min    0.000000e+00  0.000000e+00
#                  25%    8.300000e+06  1.040000e+07
#                  50%    1.150000e+07  1.300000e+07
#                  75%    1.440000e+07  1.750000e+07
#                  max    6.500000e+07  7.000000e+07

# %%
df.groupby(['Status','Gender'])['Loan_Amount'].mean()
# Out:
# Status  Gender
# N       Female    1.252162e+07
#         Male      1.466968e+07
# Y       Female    1.223600e+07
#         Male      1.448934e+07
# Name: Loan_Amount, dtype: float64

# %% [markdown]
# ### Preprocessing Data

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
categorical_data.head()
# Out:
#   Gender Married     Education Self_Employed Credit_History   Area Status
# 0   Male      No      Graduate            No            Yes  Urban      Y
# 1   Male     Yes      Graduate            No            Yes  Rural      N
# 2   Male     Yes      Graduate           Yes            Yes  Urban      Y
# 3   Male     Yes  Not Graduate            No            Yes  Urban      Y
# 4   Male      No      Graduate            No            Yes  Urban      Y

# %%
label_encoder = LabelEncoder()
for column in categorical_data.columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
scaler = StandardScaler
df[numerical_data.columns] = scaler().fit_transform(df[numerical_data.columns])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0       1        0   -0.737806          0              0          0.072991
# 1       1        1    0.253470          0              0         -0.134412
# 2       1        1   -0.737806          0              1         -0.393747
# 3       1        1   -0.737806          1              0         -0.462062
# 4       1        0   -0.737806          0              0          0.097728
#
#    Coapplicant_Income  Loan_Amount      Term  Credit_History  Area  Status
# 0           -0.554487     0.097515  0.273231               1     2       1
# 1           -0.038732    -0.152244  0.273231               1     0       0
# 2           -0.554487    -0.856110  0.273231               1     2       1
# 3            0.251980    -0.243065  0.273231               1     2       1
# 4           -0.554487    -0.004659  0.273231               1     2       1

# %%
x = df.drop('Status', axis=1)
y = df['Status']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=11)

# %% [markdown]
# ### Build Model
# create model from 3 model algorithm and find the best model for this case.

# %%
# !pip install xgboost
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.22.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
def models(x_train,y_train):

  loreg=LogisticRegression()
  loreg.fit(x_train,y_train)

  Xgb=XGBClassifier()
  Xgb.fit(x_train,y_train)

  svc=SVC()
  svc.fit(x_train,y_train)

  print('[0] Logistic Regression Training Accuracy:', loreg.score(x_train, y_train))
  print('[1] XGBoost Classifier Training Accuracy:', Xgb.score(x_train, y_train))
  print('[2] Support Vector Machine Training Accuracy:', svc.score(x_train, y_train))

  return loreg, Xgb, svc

# %% [markdown]
# Showing score from trained model

# %%
model = models(x_train,y_train)
# Out:
# [0] Logistic Regression Training Accuracy: 0.8044806517311609
# [1] XGBoost Classifier Training Accuracy: 1.0
# [2] Support Vector Machine Training Accuracy: 0.8126272912423625

# %% [markdown]
# testing and showing the conf metrics

# %%
for i in range(len(model)):
  cm = confusion_matrix(y_test, model[i].predict(x_test))
  TN, FP, FN, TP = confusion_matrix(y_test, model[i].predict(x_test)).ravel()
  print(cm)
  print('Model[{}] Testing Accuracy = "{} "'.format(i,  (TP + TN) / (TP + TN + FN + FP)))
  print()
# Out:
# [[23 17]
#  [ 2 81]]
# Model[0] Testing Accuracy = "0.8455284552845529 "
#
# [[24 16]
#  [ 8 75]]
# Model[1] Testing Accuracy = "0.8048780487804879 "
#
# [[23 17]
#  [ 2 81]]
# Model[2] Testing Accuracy = "0.8455284552845529 "

# %% [markdown]
# from the testing accuracy we can conclude that XGBoost is the best model among the other 2 models

# %%
xgboost = XGBClassifier()
fix_model = xgboost.fit(x_train, y_train)
fix_model.score(x_train, y_train)
# Out:
# 1.0

# %%
pred = fix_model.predict(x_test)
cf_matrix = confusion_matrix(y_test, pred)
#fmt='.2%'
# Visualize Confution Matrix
sns.heatmap(cf_matrix/np.sum(cf_matrix),fmt='.2%', annot=True)
plt.title('Confusion Matrix of XGBoostClassifier', fontsize=12)
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('Actual', fontsize=12)
plt.show()

# %% [markdown]
# Saving model to pickle

# %%
import pickle
with open('XGBoost_model.pkl', 'wb') as file:
    pickle.dump(fix_model, file)
